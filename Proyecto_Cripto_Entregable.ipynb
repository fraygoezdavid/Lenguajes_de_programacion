# %% [markdown]
# <a href="https://colab.research.google.com/github/fraygoezdavid/Lenguajes_de_programacion/blob/main/Proyecto_Cripto_Entregable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #INSTITUTO TECNOLÓGICO METROPOLITANO
# Ingeniería Financiera
# VII Concurso de Analítica Financiera
# The Trading Floor Experience
# Criptomonedas
# Jueves 21 de mayo de 2026 · Centro Cultural ITM
# GUÍA PARA EQUIPOS PARTICIPANTES
#
# ###_¿Qué es este concurso?_
# Cada equipo actúa como un fondo de inversión en criptomonedas. Su misión es construir una aplicación
# interactiva que analice datos históricos, proponga una idea de trading y la defienda ante inversionistas
# reales el día del evento.
# Los asistentes al evento son los inversionistas. Ellos recorren los stands, ven la app en vivo, escuchan
# el pitch de cada fondo y deciden dónde poner su capital ficticio. El fondo que mejor explique su propuesta
# capta más inversión.
# ###_Lo que deben construir_
# Una aplicación interactiva en R o Python que descargue datos en tiempo real desde Yahoo Finance el
# día del evento. No se permiten archivos CSV precargados: la app debe conectarse a la fuente en vivo.

# %%
# !pip install yfinance
# !pip install plotly
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.12/dist-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.0.13)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.9.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.0.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.15.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (5.29.6)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2026.4.22)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (13.9.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->curl_cffi>=0.7->yfinance) (3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->curl_cffi>=0.7->yfinance) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->curl_cffi>=0.7->yfinance) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.7->yfinance) (0.1.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (9.1.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (26.1)

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt


print("¡Listo para analizar cripto!")
# Out:
# ¡Listo para analizar cripto!

# %% [markdown]
# #Criptomonedas Disponibles
# - Tickers a utilizar

# %%
Cripto = {
    'Criptomonedas': ['Bitcoin', 'Ethereum ', 'Solana', 'Cardano', 'Litecoin'],
    'Simbolo': ['BTC-USD', 'ETH-USD', 'SOL-USD', 'ADA-USD', 'LTC-USD'],
    'Categoria': ['Alta capitalización', 'Alta capitalización', 'Capitalización media', 'Capitalización media', 'Capitalización media']
}
# Creación del DataFrame
df = pd.DataFrame(Cripto)

# Mostramos el DataFrame
df
# Out:
#   Criptomonedas  Simbolo             Categoria
# 0       Bitcoin  BTC-USD   Alta capitalización
# 1     Ethereum   ETH-USD   Alta capitalización
# 2        Solana  SOL-USD  Capitalización media
# 3       Cardano  ADA-USD  Capitalización media
# 4      Litecoin  LTC-USD  Capitalización media

# %%
tickers = ['BTC-USD', 'ETH-USD', 'SOL-USD', 'ADA-USD', 'LTC-USD' ]

# %% [markdown]
# #Descarga de datos general

# %%
datos = yf.download (tickers, start='2026-01-01', end='2026-05-12', interval='1d')
datos.head()
# Out:
# /tmp/ipykernel_2422/4112590837.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   datos = yf.download (tickers, start='2026-01-01', end='2026-05-12', interval='1d')
# [*********************100%***********************]  5 of 5 completed
# Price          Close                                                    \
# Ticker       ADA-USD       BTC-USD      ETH-USD    LTC-USD     SOL-USD
# Date
# 2026-01-01  0.356212  88731.984375  3000.394287  79.843811  126.761124
# 2026-01-02  0.393758  89944.695312  3124.422607  81.823280  132.133667
# 2026-01-03  0.389375  90603.187500  3125.917480  82.052773  133.298477
# 2026-01-04  0.400091  91413.492188  3140.710449  82.133148  133.899612
# 2026-01-05  0.421874  93882.554688  3226.130371  83.575470  137.989975
#
# Price           High                                                    ...  \
# Ticker       ADA-USD       BTC-USD      ETH-USD    LTC-USD     SOL-USD  ...
# Date                                                                    ...
# 2026-01-01  0.358887  88803.226562  3006.010254  79.858162  126.987114  ...
# 2026-01-02  0.395642  90884.460938  3146.984375  82.162209  132.987900  ...
# 2026-01-03  0.398342  90679.570312  3135.025635  82.757523  133.608383  ...
# 2026-01-04  0.404308  91712.585938  3160.551025  82.996727  135.354477  ...
# 2026-01-05  0.424610  94762.070312  3261.245850  84.388268  139.635590  ...
#
# Price           Open                                                    \
# Ticker       ADA-USD       BTC-USD      ETH-USD    LTC-USD     SOL-USD
# Date
# 2026-01-01  0.332836  87508.046875  2966.997314  76.777969  124.484741
# 2026-01-02  0.356212  88733.062500  3000.453125  79.843346  126.761124
# 2026-01-03  0.393761  89945.054688  3124.310303  81.823479  132.133392
# 2026-01-04  0.389380  90603.000000  3125.960205  82.052773  133.298218
# 2026-01-05  0.400092  91414.625000  3141.486328  82.133675  133.902634
#
# Price          Volume
# Ticker        ADA-USD      BTC-USD      ETH-USD    LTC-USD     SOL-USD
# Date
# 2026-01-01  531808672  18849043990  10268796662  255021763  2461653813
# 2026-01-02  968787318  46398906171  25242778003  360416066  4508641946
# 2026-01-03  546995635  20774828592  11460707919  312443399  2477037555
# 2026-01-04  646307408  26770491368  13890479323  320989435  2982580991
# 2026-01-05  905549791  53376407252  27211995956  452029892  5200675282
#
# [5 rows x 25 columns]

# %% [markdown]
# #Descarga de datos individual

# %%
btc = yf.download ('ETH-USD', start='2026-01-01', end='2026-05-12', interval='1d')
btc.head()
# Out:
# /tmp/ipykernel_2422/4265364861.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   btc = yf.download ('ETH-USD', start='2026-01-01', end='2026-05-12', interval='1d')
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open       Volume
# Ticker          ETH-USD      ETH-USD      ETH-USD      ETH-USD      ETH-USD
# Date
# 2026-01-01  3000.394287  3006.010254  2966.845215  2966.997314  10268796662
# 2026-01-02  3124.422607  3146.984375  2989.901367  3000.453125  25242778003
# 2026-01-03  3125.917480  3135.025635  3077.465820  3124.310303  11460707919
# 2026-01-04  3140.710449  3160.551025  3119.427490  3125.960205  13890479323
# 2026-01-05  3226.130371  3261.245850  3134.092773  3141.486328  27211995956

# %%
eth = yf.download ('ETH-USD', start='2026-01-01', end='2026-05-12', interval='1d')
eth.head()

# %%
sol = yf.download ('SOL-USD', start='2026-01-01', end='2026-05-12', interval='1d')
sol.head()

# %%
ada = yf.download ('ADA-USD', start='2026-01-01', end='2026-05-12', interval='1d')
ada.head()

# %%
ltc = yf.download ('LTC-USD', start='2026-01-01', end='2026-05-12', interval='1d')
ltc.head()

# %% [markdown]
# #Trabajando solo con precios de cierre

# %%
precios_cierre = datos["Close"]
precios_cierre.head()
# Out:
# Ticker       ADA-USD       BTC-USD      ETH-USD    LTC-USD     SOL-USD
# Date
# 2026-01-01  0.356212  88731.984375  3000.394287  79.843811  126.761124
# 2026-01-02  0.393758  89944.695312  3124.422607  81.823280  132.133667
# 2026-01-03  0.389375  90603.187500  3125.917480  82.052773  133.298477
# 2026-01-04  0.400091  91413.492188  3140.710449  82.133148  133.899612
# 2026-01-05  0.421874  93882.554688  3226.130371  83.575470  137.989975

# %%
##Graficando los precios de cierre
precios_cierre.plot(figsize=(20, 8))
plt.title("Precios de Cierre de las Criptomonedas")
plt.xlabel("Fecha")
plt.ylabel("Precio de Cierre(USD)")
plt.grid(True)
plt.show()

# %%
#Analizando la gráfica
precios_cierre.hist(figsize=(20, 10), bins=20)
plt.suptitle("Distribución de Precios de Cierre", fontsize=12)
plt.xlabel("Precio de Cierre")
plt.ylabel("Frecuencia")

plt.show()

# %% [markdown]
# #HASTA ACÁ HEMOS CREADO EL CÓDIGO

# %%
btc.head(5)
# Out:
# Price              Close          High           Low          Open  \
# Ticker           BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2024-01-01  44167.332031  44175.437500  42214.976562  42280.234375
# 2024-01-02  44957.968750  45899.707031  44176.949219  44187.140625
# 2024-01-03  42848.175781  45503.242188  40813.535156  44961.601562
# 2024-01-04  44179.921875  44770.023438  42675.175781  42855.816406
# 2024-01-05  44162.691406  44353.285156  42784.718750  44192.980469
#
# Price            Volume
# Ticker          BTC-USD
# Date
# 2024-01-01  18426978443
# 2024-01-02  39335274536
# 2024-01-03  46342323118
# 2024-01-04  30448091210
# 2024-01-05  32336029347

# %%
btc.describe()
# Out:
# Price           Close           High            Low           Open  \
# Ticker        BTC-USD        BTC-USD        BTC-USD        BTC-USD
# count      365.000000     365.000000     365.000000     365.000000
# mean     65888.868290   67114.172517   64434.563699   65751.583765
# std      14632.134647   14920.310187   14310.209801   14618.657810
# min      39507.367188   40127.351562   38521.894531   39518.714844
# 25%      59027.625000   60262.718750   57650.113281   59014.988281
# 50%      64118.792969   65523.222656   62783.632812   64104.738281
# 75%      69122.335938   70046.273438   67535.132812   69020.546875
# max     106140.601562  108268.445312  105291.734375  106147.296875
#
# Price         Volume
# Ticker       BTC-USD
# count   3.650000e+02
# mean    3.742215e+10
# std     2.196309e+10
# min     9.344044e+09
# 25%     2.384281e+10
# 50%     3.229276e+10
# 75%     4.314798e+10
# max     1.492189e+11

# %%
btc.columns
# Out:
# MultiIndex([( 'Close', 'BTC-USD'),
#             (  'High', 'BTC-USD'),
#             (   'Low', 'BTC-USD'),
#             (  'Open', 'BTC-USD'),
#             ('Volume', 'BTC-USD')],
#            names=['Price', 'Ticker'])

# %%
btc.shape
# Out:
# (365, 5)

# %% [markdown]
# #Riesgo: volatilidad anualizada
# - La volatilidad mide cuánto varía un activo. Anualizarla permite comparar entre activos y horizontes.
# - Calcula la volatilidad anualizada (desviación estándar × √252 días bursátiles).

# %%
vol_anual = btc['retorno'].std(1) * np.sqrt(252)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'retorno'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_25198/4246440116.py in <cell line: 0>()
# ----> 1 vol_anual = btc['retorno'].std(1) * np.sqrt(252)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4099         if is_single_key:
#    4100             if self.columns.nlevels > 1:
# -> 4101                 return self._getitem_multilevel(key)
#    4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    4157     def _getitem_multilevel(self, key):
#    4158         # self.columns is a MultiIndex
# -> 4159         loc = self.columns.get_loc(key)
#    4160         if isinstance(loc, (slice, np.ndarray)):
#    4161             new_columns = self.columns[loc]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/multi.py in get_loc(self, key)
#    3038
#    3039         if not isinstance(key, tuple):
# -> 3040             loc = self._get_level_indexer(key, level=0)
#    3041             return _maybe_to_slice(loc)
#    3042
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    3389
#    3390         else:
# -> 3391             idx = self._get_loc_single_level_index(level_index, key)
#    3392
#    3393             if level > 0 or self._lexsort_depth == 0:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2978             return -1
#    2979         else:
# -> 2980             return level_index.get_loc(key)
#    2981
#    2982     def get_loc(self, key):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'retorno'

# %% [markdown]
# #Visualización de precios y retornos (Graficos)
# - Un buen gráfico vale más que mil tablas — el jurado lo agradecerá.

# %%
# Línea de precios
fig = px.line(df, y='Close', title='Bitcoin 2024')
fig.show()

# Histograma de retornos
fig2 = px.histogram(df, x='retorno', nbins=50)
fig2.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_25198/3921587269.py in <cell line: 0>()
#       1 # Línea de precios
# ----> 2 fig = px.line(df, y='Close', title='Bitcoin 2024')
#       3 fig.show()
#       4
#       5 # Histograma de retornos
#
# NameError: name 'df' is not defined

# %% [markdown]
# #Matriz de correlación
# - Si dos cripto se mueven igual (corr ≈ 1), no diversificas. Busca pares con baja correlación.

# %%
# Calcular correlación
returns = pd.DataFrame({
  'BTC': btc['Close'].pct_change(),
  'ETH': eth['Close'].pct_change(),
  'SOL': sol['Close'].pct_change(),
  'ADA': ada['Close'].pct_change(),
})
corr = returns.corr()

import seaborn as sns
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_25198/3664484086.py in <cell line: 0>()
#       2 returns = pd.DataFrame({
#       3   'BTC': btc['Close'].pct_change(),
# ----> 4   'ETH': eth['Close'].pct_change(),
#       5   'SOL': sol['Close'].pct_change(),
#       6   'ADA': ada['Close'].pct_change(),
#
# NameError: name 'eth' is not defined

# %% [markdown]
# #Recomendación al inversor
# - Selecciona el perfil del inversor y verás qué portafolio tiene sentido recomendar.
# - La entrega final del reto: una recomendación clara, basada en datos, comprensible para alguien sin formación financiera.
